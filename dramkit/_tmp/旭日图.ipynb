# %%
import pandas as pd

# %%
fpath = './旭日图.xls'
df = pd.read_excel(fpath)
df
# Out:
#                         Term     Genes  num
# 0    mmu04510:Focal adhesion     LAMA5   13
# 1                        NaN      FLT1   14
# 2                        NaN   COL11A1   12
# 3                        NaN     ITGB3   13
# 4                        NaN      FLT4   13
# ..                       ...       ...  ...
# 204                      NaN     PDGFA   12
# 205                      NaN     ITPR3   13
# 206                      NaN     ADCY1   14
# 207                      NaN      EGFR   10
# 208                      NaN    TUBA4A   12
#
# [209 rows x 3 columns]

# %%
data
# Out:
# [<pyecharts.options.charts_options.SunburstItem at 0x2a3ef604980>,
#  <pyecharts.options.charts_options.SunburstItem at 0x2a3ef604d00>]

# %%
# -*- coding: utf-8 -*-

#声明Notebook类型，必须在引入pyecharts.charts等模块前声明
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

from pyecharts import options as opts
from pyecharts.charts import Sunburst

def sunburst(data) -> Sunburst:

    c = (
        Sunburst()
        .add(series_name="我的家庭树旭日图", data_pair=data, radius=[0, "90%"])
        .set_global_opts(title_opts=opts.TitleOpts(title="我的家庭树旭日图"),
                         toolbox_opts=opts.ToolboxOpts())
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}"))
    )
    return c

data = [
    opts.SunburstItem(
        name="爷爷",
        children=[
            opts.SunburstItem(
                name="李叔叔",
                value=15,
                children=[
                    opts.SunburstItem(name="表妹李诗诗", value=2),
                    opts.SunburstItem(
                        name="表哥李政",
                        value=5,
                        children=[opts.SunburstItem(name="表侄李佳", value=2)],
                    ),
                    opts.SunburstItem(name="表姐李诗", value=4),
                ],
            ),
            opts.SunburstItem(
                name="爸爸",
                value=10,
                children=[
                    opts.SunburstItem(name="我", value=5),
                    opts.SunburstItem(name="哥哥李海", value=1),
                ],
            ),
        ],
    ),
    opts.SunburstItem(
        name="三爷爷",
        children=[
            opts.SunburstItem(
                name="李叔叔",
                children=[
                    opts.SunburstItem(name="表哥李靖", value=1),
                    opts.SunburstItem(name="表妹李静", value=2),
                ],
            )
        ],
    ),
]

#第一次渲染时候调用load_javasrcript文件
sunburst(data).load_javascript()
#展示数据可视化图表
# sunburst(data).render('旭日图.html')
sunburst(data).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e2e0c5eb33c64131964549da09fa2df3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e2e0c5eb33c64131964549da09fa2df3 = echarts.init(
#                     document.getElementById('e2e0c5eb33c64131964549da09fa2df3'), 'white', {renderer: 'canvas'});
#                 var option_e2e0c5eb33c64131964549da09fa2df3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sunburst",
#             "name": "\u6211\u7684\u5bb6\u5ead\u6811\u65ed\u65e5\u56fe",
#             "data": [
#                 {
#                     "name": "\u7237\u7237",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "value": 15,
#                             "name": "\u674e\u53d4\u53d4",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 2,
#                                     "name": "\u8868\u59b9\u674e\u8bd7\u8bd7",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 5,
#                                     "name": "\u8868\u54e5\u674e\u653f",
#                                     "target": "blank",
#                                     "children": [
#                                         {
#                                             "value": 2,
#                                             "name": "\u8868\u4f84\u674e\u4f73",
#                                             "target": "blank"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "value": 4,
#                                     "name": "\u8868\u59d0\u674e\u8bd7",
#                                     "target": "blank"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 10,
#                             "name": "\u7238\u7238",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 5,
#                                     "name": "\u6211",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 1,
#                                     "name": "\u54e5\u54e5\u674e\u6d77",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "name": "\u4e09\u7237\u7237",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "name": "\u674e\u53d4\u53d4",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 1,
#                                     "name": "\u8868\u54e5\u674e\u9756",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 2,
#                                     "name": "\u8868\u59b9\u674e\u9759",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "radius": [
#                 0,
#                 "90%"
#             ],
#             "highlightPolicy": "descendant",
#             "nodeClick": "rootToNode",
#             "sort": "desc",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u6211\u7684\u5bb6\u5ead\u6811\u65ed\u65e5\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "xAxisIndex": false,
#                 "yAxisIndex": false,
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a
