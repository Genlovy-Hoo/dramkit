# %%
from pyecharts.charts import Sunburst
from pyecharts import options as opts

"""
Gallery 使用 pyecharts 1.2.1
参考地址: https://www.echartsjs.com/examples/editor.html?c=sunburst-simple

目前无法实现的功能:

1、暂无
"""
data = [
    {
        "name": "mmu04510",
        "itemStyle": {"color": "#9d5433"},
        "children": [
            {"name": "LAMA5", "value": 1, "itemStyle": {"color": "#794752"}},
            {"name": "FLT1", "value": 1, "itemStyle": {"color": "#794752"}},
            {"name": "COL11A1", "value": 1, "itemStyle": {"color": "#794752"}},
            {"name": "ITGB3", "value": 1, "itemStyle": {"color": "#794752"}},
            {"name": "FLT4", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "RASGRF1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PDGFA", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ARHGAP5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "EGFR", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PIK3CG", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYLK", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ACTG1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYL12B", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "CCND1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PDGFD", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "SPP1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGAV", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "VAV3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "JUN", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA4", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ACTN1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "VEGFD", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PGF", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "COL5A2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ZYX", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA7", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "COL4A5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA6", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MET", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYL9", "value": 1, "itemStyle": {"color": "#794752"}},
  
        ],
    },
    
    {
        "name": "mmu04151",
        "itemStyle": {"color": "#975e6d"},
        "children": [
            {"name": "LAMA5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "FLT1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "CSF1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "IRS1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PKN3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "COL11A1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGB3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "FLT4", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PDGFA", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "EFNA5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "IL2RG", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "EGFR", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PIK3CG", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GNGT2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "CCND1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYC", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PDGFD", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "SPP1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGAV", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA4", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "F2R", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "VEGFD", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "NGF", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GNG12", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PGF", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "EFNA1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "FGF16", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "CCNE2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "CCNE1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GNB2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "KIT", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "COL5A2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA7", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "COL4A5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA6", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PIK3AP1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MET", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "SGK2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "TLR2", "value": 1, "itemStyle": {"color": "#794752"}},
        ],
    },
    
    {
        "name": "mmu04810",
        "itemStyle": {"color": "#e0719c"},
        "children": [
            {"name": "CHRM3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ARPC1B", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGB3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PDGFA", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "EGFR", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PIK3CG", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYLK", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ACTG1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYL12B", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PDGFD", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGAV", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GIT1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "VAV3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA4", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ACTN1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "F2R", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GNG12", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "FGF16", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MRAS", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "APC", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA7", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA6", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ARHGEF7", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYL9", "value": 1, "itemStyle": {"color": "#794752"}},
        ],
    },
    
    {
        "name": "mmu04611",
        "itemStyle": {"color": "#f99e1c"},
        "children": [
            {"name": "LYN", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GUCY1A2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGB3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "COL11A1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "F2R", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITPR3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ADCY1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MAPK12", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PIK3CG", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYL12B", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYLK", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ACTG1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GP9", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PLCB4", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "COL5A2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PLCG2", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ORAI1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "F2RL3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "LAMA5", "value": 1, "itemStyle": {"color": "#794752"}},
        ],
    },
    
    {
        "name": "mmu04512",
        "itemStyle": {"color": "#ef5a78"},
        "children": [
            {"name": "VAV3", "value": 1, },{"name": "ITGA4", "value": 1, },{"name": "ACTN1", "value": 1, },{"name": "F11R", "value": 1, },{"name": "ARHGAP5", "value": 1, },{"name": "MAPK12", "value": 1, },{"name": "PIK3CG", "value": 1, },{"name": "MYL12B", "value": 1, },{"name": "ACTG1", "value": 1, },{"name": "ICAM1", "value": 1, },{"name": "PLCG2", "value": 1, },{"name": "ESAM", "value": 1, },{"name": "MYL9", "value": 1, },{"name": "SIPA1", "value": 1, },{"name": "RAPGEF3", "value": 1, },{"name": "RAPGEF4", "value": 1, },
        ],
    },
    
    {
        "name": "mmu04670",
        "itemStyle": {"color": "#f7f1bd"},
        "children": [
            {"name": "CHRM3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ARPC1B", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGB3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PDGFA", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "EGFR", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PIK3CG", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYLK", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ACTG1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYL12B", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "PDGFD", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGAV", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GIT1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "VAV3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA4", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA3", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ACTN1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA1", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "F2R", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "GNG12", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "FGF16", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MRAS", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "APC", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA7", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA6", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ITGA5", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "ARHGEF7", "value": 1, "itemStyle": {"color": "#794752"}},{"name": "MYL9", "value": 1, "itemStyle": {"color": "#794752"}},
        ],
    },
    
    {
        "name": "mmu04022",
        "itemStyle": {"color": "#da1d23"},
        "children": [
            {"name": "GUCY1A2", "value": 1, },{"name": "MEF2C", "value": 1, },{"name": "IRS1", "value": 1, },{"name": "NPR1", "value": 1, },{"name": "PDE2A", "value": 1, },{"name": "ATP1A3", "value": 1, },{"name": "ITPR3", "value": 1, },{"name": "ADCY1", "value": 1, },{"name": "ATP1B2", "value": 1, },{"name": "ATP1B1", "value": 1, },{"name": "MYLK", "value": 1, },{"name": "SLC8A2", "value": 1, },{"name": "NFATC4", "value": 1, },{"name": "NPPB", "value": 1, },{"name": "RGS2", "value": 1, },{"name": "PLCB4", "value": 1, },{"name": "MRVI1", "value": 1, },{"name": "MYL9", "value": 1, },
        ],
    },
    
    {
        "name": "mmu04514",
        "itemStyle": {"color": "#dd4c51"},
        "children": [
            {"name": "CADM3", "value": 1, },{"name": "ITGA4", "value": 1, },{"name": "NRXN1", "value": 1, },{"name": "F11R", "value": 1, },{"name": "ICAM1", "value": 1, },{"name": "SPN", "value": 1, },{"name": "SELP", "value": 1, },{"name": "ALCAM", "value": 1, },{"name": "NCAM1", "value": 1, },{"name": "ITGA6", "value": 1, },{"name": "NRCAM", "value": 1, },{"name": "ESAM", "value": 1, },{"name": "ITGAV", "value": 1, },{"name": "CD34", "value": 1, },{"name": "H2-D1", "value": 1, },
        ],
    },
    
    {
        "name": "mmu04062",
        "itemStyle": {"color": "#3e0317"},
        "children": [
            {"name": "LYN", "value": 1,},{"name": "VAV3", "value": 1, },{"name": "CXCL1", "value": 1, },{"name": "ARRB1", "value": 1, },{"name": "ADCY1", "value": 1, },{"name": "GNG12", "value": 1, },{"name": "CXCL2", "value": 1, },{"name": "PIK3CG", "value": 1, },{"name": "CXCL5", "value": 1, },{"name": "CXCL10", "value": 1, },{"name": "PREX1", "value": 1, },{"name": "PLCB4", "value": 1, },{"name": "GNGT2", "value": 1, },{"name": "GNB2", "value": 1, },{"name": "CCL5", "value": 1, },{"name": "ELMO1", "value": 1, },{"name": "PF4", "value": 1, },
        ],
    },
    
    {
        "name": "mmu04540",
        "itemStyle": {"color": "#ad213e"},
        "children": [
            {"name": "GUCY1A2", "value": 1, },{"name": "PLCB4", "value": 1, },{"name": "TUBB3", "value": 1, },{"name": "PDGFD", "value": 1, },{"name": "PDGFA", "value": 1, },{"name": "ITPR3", "value": 1, },{"name": "ADCY1", "value": 1, },{"name": "EGFR", "value": 1, },{"name": "TUBA4A", "value": 1, },
        ],
    },

]

c = (
    Sunburst(init_opts=opts.InitOpts(width="1000px", height="600px"))
    .add(
        "",
        data_pair=data,
        highlight_policy="ancestor",
        radius=[0, "95%"],
        #node_click= "rootToNode",
        sort_="null",
        
        levels=[
             {},
            {"r0": "30%", "r": "70%", "label": {"align": "center"}},
            {
                "r0": "70%",
                "r": "72%",
                "label": { "position": "outside","padding": 3, "silent": False},
                "TextStyle":{"font_size":4,},
                "itemStyle": {"borderWidth": 3,"font_size":4,},
            },
        ],
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="GENESunburst"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}"))
    .render("GENEdrink_flavors.html")
)

# %%
len(data)
# Out:
# 10
